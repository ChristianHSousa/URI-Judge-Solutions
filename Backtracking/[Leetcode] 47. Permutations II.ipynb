# %% [markdown]
# ![image.png](attachment:7fffb7b4-e45f-4cb3-8420-cf3abf77dc2f.png)

# %%
class Solution(object):
    def permuteUnique(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
